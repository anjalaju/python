# %%
try:
    no1=int(input("Enter the first no:"))
    no2=int(input("Enter the second no:"))
    print("The sum of the no is:",no1/no2)
except ZeroDivisionError:
    print("cant divide by zero")
except ValueError:
    print("Please enter a valid number")
except Exception as e:
    print("You got an error:",e)
finally:
    print("Called")

# %%
num1=int(input("Entre the 1st nu:"))
num2=int(input("Entre the 2nd nu:"))
x=int(num1)
y=int(num2)
result=x+y
print("*"*100)
print("The result isss:",str(result))
print("*"*100)

# %%
for i in "Anjal":
    print(i)

# %%
for i in range(1,11):
    print(i)

# %%
nnumber=int(input("Enter the number:"))
for i in range(1,11):
    print(i,"*",nnumber,"=",i*nnumber)

# %%
def add():
    nu1=int(input("Enter tge first mu:"))
    nu2=int(input("Enter tge sec mu:"))
    print("The sum of the number:",nu1+nu2)
add()

# %%
class demo():
    name="Anjal"
    def hello(self):
        print("hello world")
    def hi(self):
        print("welcome")
new=demo()
new.hello()
new.hi()

# %%
class demo():
    name= "Anjal"
    def hello(self):
        print("Hello world")
    def hi(self):
        print("Welcome")    
class child(demo):
    pass
new=child()
new.hello() 
new.hi()

# %%
class demo():
    name= "Anjal"
    def hello(self):
        print("Hello world")
    def hi(self):
        print("Welcome")    
class child(demo):
    def house(self):
        print("this is the house")
    def home(self):
        print("This is the hpme")
class child2(child):
    def ho(self):
        print("this is the house")
    def hom(self):
        print("This is the hpme")
new=child2()
new.hello() 
new.hi() 
new.house()  
new.home()  
print(new.name)

# %%
class main():
    def ma(self):
        print("Thi is the main")
class demo():
    name= "Anjal"
    def hello(self):
        print("Hello world")
    def hi(self):
        print("Welcome")    
class child(demo):
    def house(self):
        print("this is the house")
    def home(self):
        print("This is the hpme")
class anjal(main,child):
    def aa(self):
        print("thi is the aa")
new=anjal()
new.hello()  
new.house()         
new.ma()         
new.aa()

# %%
              # over riding
class Demo():
    def hello(self):
        print("This is the hello fn:")
    def hi(self):
        print("This is the hi fn:")        
class child(Demo):
    def hello(self):
        print("This is the child class fn:")
x=child()
x.hello()
y=Demo()
y.hello()
# Out:
# This is the child class fn:
# This is the hello fn:

# %%
    #   access modifier
class ddemo():
    _name="Aju"
    def  hi(self):
        self.__hello()
        print("welcome")
    def _welcome(self):
        print("welcome to")
    def __hello(self):
        print("hello world")
x=ddemo()
x.hi()     
x._welcome()   
print(x._name)

# %%
  #   access modifier wit constructor
class Demo():
    def __init__(self):
        self.name="Anjal"
    def hi(self):
        print("Hi fun")
    def _hello(self):
        print("hello fn")
    def ___welcome(self):
        print("welcome fn")
    def help(self):
        self.___welcome()
nn=Demo()
nn.hi()     
nn._hello()  
nn.help() 
print(nn.name)

# %%
# using for condition
nnumber=int(input("Enter the number:"))
for i in range(1,11):
    print(i,"*",nnumber,"=",i*nnumber)

# %%
# using if condition
def table(x,y):
    if y==0:
        return
    table(x,y-1)
    print(y,"*",x,"=",x*y)
max=10
table(2,max)
# Out:
# 1 * 2 = 2
# 2 * 2 = 4
# 3 * 2 = 6
# 4 * 2 = 8
# 5 * 2 = 10
# 6 * 2 = 12
# 7 * 2 = 14
# 8 * 2 = 16
# 9 * 2 = 18
# 10 * 2 = 20

# %%
# functiom
def add():
    firstno=int(input("Enter the 1st no:"))
    secondno=int(input("Enter the 2nd no:"))
    print(" the result is:",firstno+secondno)
add()

# %%
# function with para
def add(firstno,secondno):
    print(" the result is:",firstno+secondno)

add(3,3)
# Out:
#  the result is: 6

# %%
# function with return
def add(x,y):
    ans=x+y
    return ans
firstno=int(input("Enter the 1st no:"))
secondno=int(input("Enter the 2nd no:"))
result=add(firstno,secondno)
print(" the result is:",result)
# Out:
#  the result is: 5

# %%
# function with optional
def add(x,y,z=10):
    ans=x+y+z
    return ans
firstno=int(input("Enter the 1st no:"))
secondno=int(input("Enter the 2nd no:"))
result=add(firstno,secondno,20)
print(" the result is:",result)

# %%
firstname="Anjal"
lastname=str("aju")
fullname=firstname+" "+lastname
print(fullname)
print(len(fullname))
print(fullname[1])
# Out:
# Anjal aju
# 9
# n

# %%
  
name = "anjal"
if type(name) == str:
    print("welcome:", name)
else:
    print("Please enter a valid name")
# Out:
# welcome: anjal
