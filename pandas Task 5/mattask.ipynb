# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[20,30,18,25,33]
y=[10,23,14,28]
plt.figure(figsize=(12, 8)) 
for i in range(1, 9):
    plt.subplot(4, 2, i) 
    plt.plot(x,"m",label="x_point",marker="o",ms=8,mec="k",mfc="b",linewidth=3,linestyle="-.",color="r")
    plt.plot(y,"c",label="y_point",marker="o",ms=8,mec="k",mfc="c",linewidth=3,linestyle="-.",color="g")
    plt.legend(shadow=True,loc="upper right",title="Axis",title_fontsize=10,fontsize=8)
    plt.title("Graph " + str(i))
    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ANJAL\AppData\Local\Temp\ipykernel_10300\2543658018.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "m" (-> color=(0.75, 0.0, 0.75, 1)). The keyword argument will take precedence.
#   plt.plot(x,"m",label="x_point",marker="o",ms=8,mec="k",mfc="b",linewidth=3,linestyle="-.",color="r")
# C:\Users\ANJAL\AppData\Local\Temp\ipykernel_10300\2543658018.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "c" (-> color=(0.0, 0.75, 0.75, 1)). The keyword argument will take precedence.
#   plt.plot(y,"c",label="y_point",marker="o",ms=8,mec="k",mfc="c",linewidth=3,linestyle="-.",color="g")

# %%
x=[20,30,18,25,33]
y=[10,23,14,28]
plt.figure(figsize=(12, 8)) 
for i in range(1, 9):
    plt.subplot(4, 4, i) 
    plt.plot(x)
    plt.plot(y)
plt.tight_layout()
plt.show()

# %%
x=[2,5,6,8,9]
y=[20,30,10,25,33]
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("x")
x=[2,5,6,8,9]
y=[20,30,10,25,33]
plt.subplot(2,2,2)
plt.plot(x,y)
plt.title("y")
x=[2,5,6,8,9]
y=[20,30,10,25,33]
plt.subplot(2,2,4)
plt.plot(x,y)
plt.title("z")
plt.show()

# %%
x=[20,30,18,25,33]
y=[10,23,14,28]
plt.figure(figsize=(12, 8)) 
plt.show()

# %%
import matplotlib.pylab as plt
x=[11,13,19,24,15]
y=[26,17,18,29,23]
# plt.figure(figsize=(10,5))
plt.figure(figsize=(12, 8)) 
plt.title("Graphz")
plt.subplot(4,4,1)
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,2)
x=[29,21,20,19,17]
y=[22,23,24,25,26]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,3)
x=[13,14,15,16,17]
y=[10,11,12,14,15]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,4)
x=[9,8,5,6,3]
y=[8,7,6,5,9]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,5)
x=[9,7,6,5,4]
y=[3,4,2,1,2]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,6)
x=[9,6,7,5,4]
y=[1,9,2,8,3]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,7)
x=[1,3,5,7,9]
y=[2,4,6,8,10]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,8)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,9)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,10)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,11)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,12)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,13)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,14)
x=[11,13,19,24,15]
y=[26,17,18,29,23]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,15)
x=[11,13,19,24,15]
y=[26,17,18,29,23]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,16)
x=[11,13,19,24,15]
y=[26,17,18,29,23]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
var=plt.gca()
var.spines["top"].set_visible(False)
var.spines["right"].set_visible(False)
plt.show()

# %%
x = [2, 5, 6, 8, 9]
y = [12, 10, 17, 14, 11]
plt.figure(figsize=(10,5))
plt.subplot(4,4,1)
plt.plot(x,y,"mo-")
plt.xlabel("x_axis",loc="right")
plt.ylabel("y_axis",loc="top")
plt.title("a_point") 

plt.subplot(4,4,2)
plt.plot(x,y,"ro-")
plt.xlabel("x_axis",loc="right")
plt.ylabel("y_axis",loc="top")
plt.title("b_point")

plt.subplot(4,4,3)
plt.plot(x,y,"co-")
plt.xlabel("x_axis",loc="right")
plt.ylabel("y_axis",loc="top")
plt.title("c_point")

plt.subplot(4,4,4)
plt.plot(x,y,"bo-")
plt.xlabel("x_axis",loc="right")
plt.ylabel("y_axis",loc="top")
plt.title("d_point")

plt.subplot(4,4,5)
plt.plot(x,y,"go-")
plt.xlabel("x_axis",loc="right")
plt.ylabel("y_axis",loc="top")
plt.title("e_point")

plt.subplot(4,4,6)
plt.plot(x,y,"o-")
plt.xlabel("x_axis",loc="right")
plt.ylabel("y_axis",loc="top")
plt.title("x_point")

plt.subplot(4,4,7)
plt.plot(x,y,"ro-")
plt.xlabel("x_axis",loc="right")
plt.ylabel("y_axis",loc="top")
plt.title("y_point")

plt.subplot(4,4,8)
plt.plot(x,y,"bo-")
plt.xlabel("x_axis",loc="right")
plt.ylabel("y_axis",loc="top")
plt.title("z_point")

plt.tight_layout()
plt.show()

# %%
# import pandas as pd
# df=pd.read_csv("profit_and_loss.csv")
# for i in df["Profit/Loss"]:
#     if i<-1:
#         var+=i
#         print(var)
# # plt.bar(df["Year"],df["Profit/Loss"])
# # plt.bar(df.var)

# %%
# import pandas as pd
# df=pd.read_csv("profit_and_loss.csv")
# plt.grid(linestyle="-.")
# plt.bar(x,y)
# plt.show()
