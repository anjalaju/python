# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv("engine_perfomence.csv")
df
# Out:
#      Engine_Speed_RPM  Fuel_Efficiency
# 0          500.000000     -2458.934731
# 1          513.026052     -2433.443544
# 2          526.052104     -2409.403597
# 3          539.078156     -2382.461235
# 4          552.104208     -2356.380454
# ..                ...              ...
# 495       6947.895792     -6193.962316
# 496       6960.921844     -6235.515689
# 497       6973.947896     -6276.468124
# 498       6986.973948     -6318.931002
# 499       7000.000000     -6360.527214
#
# [500 rows x 2 columns]

# %%
x=df[["Engine_Speed_RPM"]]
y=df["Fuel_Efficiency"]

# %%
poly_feature=PolynomialFeatures(degree=2)
x_feature=poly_feature.fit_transform(x)
x_feature
# Out:
# array([[1.00000000e+00, 5.00000000e+02, 2.50000000e+05],
#        [1.00000000e+00, 5.13026052e+02, 2.63195730e+05],
#        [1.00000000e+00, 5.26052104e+02, 2.76730816e+05],
#        ...,
#        [1.00000000e+00, 6.97394790e+03, 4.86359493e+07],
#        [1.00000000e+00, 6.98697395e+03, 4.88178049e+07],
#        [1.00000000e+00, 7.00000000e+03, 4.90000000e+07]], shape=(500, 3))

# %%
x_train,X_test,y_train,y_test=train_test_split(x_feature,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([-1900.225163  ,  -919.79739456, -2210.05912712,   -52.4729666 ,
#         -484.60267561, -2731.52150971, -2284.81707236,  -273.06013221,
#        -1002.20683993, -4480.47441847, -2230.91853609,    39.75256288,
#        -3070.46133664,  -750.4418802 , -2136.52285676, -2569.38164551,
#        -6194.35591222, -1739.41955521, -1004.86583661, -3128.85169093,
#        -5990.35046984, -6030.88007501,  -486.48970552, -1787.1666281 ,
#         -871.98062717, -4874.03953895, -6276.90828075,    15.34040789,
#         -521.01714415, -1330.02434549, -5398.69539065, -1368.86790176,
#        -4136.94081887,    15.7478348 , -2408.05421171, -1310.80617984,
#        -3158.25048056,  -968.83583682,    20.24855092, -1088.00982662,
#        -2464.00323577,  -624.09502632, -5789.73856879,    36.79487153,
#        -1674.0921146 ,  -856.31318801, -2459.88607962, -2181.53001794,
#        -3337.49379303, -1919.59869626,  -936.00780033,    33.36562467,
#         -211.84782822, -3187.78501184,    39.96689712, -1232.35317129,
#          -90.88067289, -2012.94606646,    30.14342956,  -840.78149051,
#        -6153.28334044,  -293.27208331, -1126.0903142 , -5710.44399994,
#         -825.38553466, -1547.10225799, -4515.57435752, -1405.12367049,
#         -104.06238013, -2649.84074017, -1699.16314994, -1468.35227136,
#         -451.23258129,  -612.83666038, -1021.77639416,  -812.52699488,
#         -352.79125787,  -985.45346755, -4657.33153026, -5021.22637781,
#          -57.55255682,  -780.01211703, -5475.81809305,    13.11159433,
#        -1090.77604091,  -664.9889694 ,    30.40075182, -3307.28055349,
#         -938.58102292,  -462.84921438, -2386.39471582, -5284.02939944,
#        -1923.24409494, -1143.95106333, -3839.36649056, -1592.21298943,
#         -721.41460999,  -887.78380798, -4069.86299878, -2084.38188146])

# %%
msc=mean_squared_error(y_pred,y_test)
print(f"mean_squared_error:{msc}")
rmsc=np.sqrt(msc)
print(f"root_mean_squared_error:{rmsc}")
score=r2_score(y_pred,y_test)
print(f"score:{score}")
# Out:
# mean_squared_error:0.5675835058790837
# root_mean_squared_error:0.7533813814258246
# score:0.9999998226524639

# %%
a=model.predict(poly_feature.transform(x))

# %%
plt.figure(figsize=(10,5))
plt.scatter(x,y,c="r")
plt.plot(x,a,c="k")
plt.show()

# %%
new_data=np.array([[539.078156]])
poly=poly_feature.transform(new_data)
predict=model.predict(poly)
predict
# Out:
# c:\Users\ANJAL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([-2382.34189085])

# %%
plt.figure(figsize=[10,6])
plt.scatter(x,y,color="red")
plt.scatter(new_data,predict)
plt.show()
