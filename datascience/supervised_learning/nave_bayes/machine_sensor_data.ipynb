# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split    
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df=pd.read_csv('machine_sensor_data.csv')
df
# Out:
#      Temperature  Vibration          RPM   Pressure  Status
# 0      79.967142   3.750627  1463.420712  26.391312  Normal
# 1      73.617357   2.587164  1774.975284  30.884104  Faulty
# 2      81.476885   3.076897  1370.807164  27.266600  Normal
# 3      90.230299   2.630180  1340.161599  28.641724  Faulty
# 4      72.658466   2.652403  1403.451296  38.367260  Faulty
# ..           ...        ...          ...        ...     ...
# 795    85.531529   2.192215  1210.070956  20.599950  Faulty
# 796    74.604448   3.495323  1315.628037  33.563560  Normal
# 797    81.815007   4.645996  1299.208526  20.584249  Faulty
# 798    75.283184   3.016635  1541.453466  28.138405  Normal
# 799    75.297561   2.417598  1513.868867  32.186566  Normal
#
# [800 rows x 5 columns]

# %%
x=df.drop('Status',axis=1)
y=df['Status']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Faulty', 'Faulty', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Faulty', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Faulty', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Faulty', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Faulty', 'Normal',
#        'Faulty', 'Faulty', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Faulty', 'Normal',
#        'Normal', 'Faulty', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Faulty', 'Normal', 'Faulty', 'Normal', 'Faulty', 'Normal',
#        'Normal', 'Normal', 'Faulty', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Faulty', 'Normal', 'Normal', 'Faulty',
#        'Normal', 'Normal', 'Normal', 'Faulty', 'Faulty', 'Normal',
#        'Faulty', 'Normal', 'Faulty', 'Faulty', 'Normal', 'Normal',
#        'Faulty', 'Normal', 'Faulty', 'Normal', 'Faulty', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Faulty', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Faulty', 'Faulty',
#        'Faulty', 'Normal', 'Faulty', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Faulty', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Faulty', 'Normal', 'Normal', 'Normal',
#        'Faulty', 'Faulty', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Faulty', 'Normal', 'Normal', 'Faulty', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Faulty', 'Normal', 'Normal', 'Faulty',
#        'Normal', 'Normal', 'Normal', 'Faulty'], dtype='<U6')

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[36, 24],
#        [ 2, 98]])

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8375

# %%
plt.figure(figsize=(10,6))
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
new_data=np.array([[85.531529,2.192215,1210.070956,20.599950]])
predict=model.predict(new_data)
predict
# Out:
# c:\Users\ANJAL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['Normal'], dtype='<U6')
