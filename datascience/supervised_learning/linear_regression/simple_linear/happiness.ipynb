# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv("happiness.csv")
df
# Out:
#      GDP_per_capita  Happiness_Score
# 0          30275.94             3.60
# 1          76081.79             5.14
# 2          58693.52             5.12
# 3          48093.35             4.71
# 4          12903.48             2.93
# ..              ...              ...
# 995         7780.77             1.73
# 996        73426.43             5.37
# 997        11377.08             2.55
# 998        76043.87             5.59
# 999        35957.46             3.45
#
# [1000 rows x 2 columns]

# %%
x=df[["GDP_per_capita"]]
y=df["Happiness_Score"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([3.60041332, 5.29407004, 3.91833761, 3.50403545, 5.81285632,
#        5.88829942, 3.91777385, 5.48634465, 2.37525905, 4.13644771,
#        5.38074768, 5.11786957, 4.19019377, 2.95534221, 2.57755464,
#        2.45222376, 5.57940794, 2.52452439, 3.33154511, 3.09256772,
#        5.12194347, 4.62771212, 2.19067167, 3.18260981, 4.25284112,
#        4.92810668, 4.59365157, 4.79575109, 2.82510426, 5.61833108,
#        4.58853327, 5.89728529, 2.933609  , 5.95337097, 2.51157805,
#        5.56806192, 3.20815633, 4.58195301, 2.22297495, 3.38444236,
#        3.75088098, 4.1517718 , 2.21838227, 2.24105378, 2.45159742,
#        4.64633564, 3.77270123, 3.20275786, 2.43605427, 3.52851313,
#        4.11778508, 2.98267583, 5.96830978, 4.03276154, 3.54393746,
#        4.48144745, 3.19610035, 2.19985557, 4.32893061, 5.24063739,
#        5.11290675, 4.44395644, 3.0086052 , 2.74492277, 2.58876816,
#        4.09298909, 4.47456699, 2.72328   , 5.12165744, 4.73082915,
# ...

# %%
mse=mean_squared_error(y_test,y_pred)
print(f"Mean Squared Error: {mse}")
rmse=np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
score=r2_score(y_test,y_pred)
print(f"R2 Score: {score}")
# Out:
# Mean Squared Error: 0.21438217574534646
# Root Mean Squared Error: 0.4630142284480537
# R2 Score: 0.8576481464823911

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,color="green")
plt.plot(x_test,y_pred,color="red")
plt.xlabel("GDP per capita")
plt.ylabel("Happiness Score")
plt.title("GDP per capita vs Happiness Score")
plt.show()

# %%
new_data=np.array([[300]])
predicted_happiness=model.predict(new_data)
print(f"Predicted Happiness Score for a GDP per capita of 50: {predicted_happiness[0]}")
plt.scatter(x,y,color="green")
plt.scatter(new_data,predicted_happiness,color="red",marker="*",s=100)
plt.plot(x_test,y_pred,color="blue")
plt.xlabel("GDP per capita")
plt.ylabel("Happiness Score")
plt.title("GDP per capita vs Happiness Score")
plt.show()
# Out:
# Predicted Happiness Score for a GDP per capita of 50: 2.0978381792098
# c:\Users\ANJAL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
