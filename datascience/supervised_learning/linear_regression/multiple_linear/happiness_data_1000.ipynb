# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv('happiness_data_1000.csv')
df
# Out:
#      GDP_per_capita  Social_support  Healthy_life_expectancy  Freedom  \
# 0          30275.94            0.19                    51.78     0.67
# 1          76081.79            0.54                    51.11     0.80
# 2          58693.52            0.87                    80.78     0.25
# 3          48093.35            0.73                    51.23     0.62
# 4          12903.48            0.81                    52.24     0.57
# ..              ...             ...                      ...      ...
# 995         7780.77            0.66                    78.94     0.44
# 996        73426.43            0.96                    47.08     0.33
# 997        11377.08            0.07                    53.94     0.39
# 998        76043.87            0.06                    53.05     0.53
# 999        35957.46            0.28                    79.21     0.16
#
#      Generosity  Corruption_perception  Happiness_Score
# 0          0.26                   0.39             4.48
# ...

# %%
x=df.drop('Happiness_Score',axis=1)
y=df['Happiness_Score']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([5.51164225, 6.47527945, 6.49893543, 5.95329662, 4.43824559,
#        5.76266278, 3.33724713, 6.1141551 , 5.29534836, 6.07353337,
#        7.25672951, 6.08695846, 7.11429095, 5.89990035, 5.98231028,
#        5.22498545, 5.51403434, 3.20089763, 5.3163344 , 4.46939719,
#        6.45176453, 5.57119015, 5.01659751, 7.15155625, 5.02907162,
#        6.17971164, 7.36960567, 5.24988505, 5.05502796, 6.92435516,
#        6.67208538, 6.92334412, 4.58848429, 7.6140082 , 5.58201727,
#        6.78278004, 4.03258966, 7.39878521, 4.09780842, 7.06160327,
#        5.37872496, 5.37202816, 4.30553122, 3.6664389 , 5.89737966,
#        7.15471589, 6.44816095, 4.47179189, 4.42360506, 3.56376953,
#        5.05669462, 4.5145438 , 7.86967063, 6.10972942, 5.27267617,
#        4.36912824, 6.22704343, 2.99628734, 4.9979174 , 6.14869802,
#        5.02593876, 8.41727547, 4.94858332, 7.01171019, 3.19568807,
#        4.5919247 , 5.24746954, 3.61029497, 6.72200054, 5.22033459,
# ...

# %%
mse=mean_squared_error(y_pred,y_test)
print(f"mean_squared_error:{mse}")
rmse=np.sqrt(mse)
print(f"root_mean_squared_error:{rmse}")
score=r2_score(y_pred,y_test)
print(f"r2_score:{score}")
# Out:
# mean_squared_error:0.10736358914182854
# root_mean_squared_error:0.32766383557211276
# r2_score:0.9332745886440335

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,y_pred,c='r' ,marker='o')
plt.plot([y_test.min(), y_test.max()],[y_pred.min(), y_pred.max()],c='g')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# %%
	# GDP_per_capita	Social_support	Healthy_life_expectancy	Freedom	Generosity	Corruption_perception	Happiness_Score
new_data=pd.DataFrame({
    'GDP_per_capita': [12000],
    'Social_support': [0.5],
    'Healthy_life_expectancy': [50],
    'Freedom': [0.5],
    'Generosity': [0.5],
    'Corruption_perception': [0.5]
})
predict=model.predict(new_data)
print(predict)
plt.scatter(y_test,y_pred,c='r' ,marker='o')
plt.plot([y_test.min(), y_test.max()],[y_pred.min(), y_pred.max()],c='g')
plt.plot(new_data,predict,c='b',marker='o')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()





# new_data=pd.DataFrame({
#     'GDP_per_capita': [2000],
#     'Social_support': [0.5],
#     'Healthy_life_expectancy': [5],
#     'Freedom': [0.5],
#     'Generosity': [0.5],
#     'Corruption_perception': [0.5]
# })
# predict=model.predict(new_data)
# print(predict)
# plt.scatter(y_test,y_pred,c='r' ,marker='o')
# plt.plot([y_test.min(), y_test.max()],[y_pred.min(), y_pred.max()],c='g')
# plt.plot(predict, 'm-.')
# plt.xlabel('Actual Values')
# plt.ylabel('Predicted Values')
# plt.show()
# Out:
# [4.71346143]
