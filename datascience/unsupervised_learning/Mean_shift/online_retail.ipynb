# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import MeanShift,estimate_bandwidth

# %%
df=pd.read_csv("online_retail_1000.csv")
df.drop(columns="UserID",inplace=True)
df
# Out:
#      Session_Time_Min  Pages_Visited  Clicks  Bounce_Rate  \
# 0                 110             34     170        48.02
# 1                 127             21      28        28.83
# 2                  67             48     101        55.14
# 3                  99             33     106        55.40
# 4                  18             39      43        16.65
# ..                ...            ...     ...          ...
# 995               129              6      62        82.43
# 996               107             22      61        85.46
# 997               118             16      55        49.62
# 998                45             37      17        81.38
# 999                66             10     186        49.92
#
#      Items_Added_To_Cart  Purchase_Amount
# 0                     11          4696.93
# 1                      6           488.71
# 2                      6           857.20
# 3                      2          1510.72
# 4                      0          3832.19
# ..                   ...              ...
# 995                    4          3309.58
# 996                   11          4749.83
# 997                    4          2562.04
# 998                    3          4400.65
# 999                    0          4856.99
#
# [1000 rows x 6 columns]

# %%
x=df

# %%
bandwidth=estimate_bandwidth(x,quantile=0.2)
bandwidth
# Out:
# np.float64(566.9944127206646)

# %%
model=MeanShift(bandwidth=bandwidth)
model.fit(x)
# Out:
# MeanShift(bandwidth=np.float64(566.9944127206646))

# %%
n=model.cluster_centers_

# %%
m=model.labels_

# %%
plt.scatter(n[:,1],n[:,3],marker="*",s=200)
plt.scatter(df["Pages_Visited"],df["Bounce_Rate"],c=m)
plt.show()

# %%
df
# Out:
#      Session_Time_Min  Pages_Visited  Clicks  Bounce_Rate  \
# 0                 110             34     170        48.02
# 1                 127             21      28        28.83
# 2                  67             48     101        55.14
# 3                  99             33     106        55.40
# 4                  18             39      43        16.65
# ..                ...            ...     ...          ...
# 995               129              6      62        82.43
# 996               107             22      61        85.46
# 997               118             16      55        49.62
# 998                45             37      17        81.38
# 999                66             10     186        49.92
#
#      Items_Added_To_Cart  Purchase_Amount
# 0                     11          4696.93
# 1                      6           488.71
# 2                      6           857.20
# 3                      2          1510.72
# 4                      0          3832.19
# ..                   ...              ...
# 995                    4          3309.58
# 996                   11          4749.83
# 997                    4          2562.04
# 998                    3          4400.65
# 999                    0          4856.99
#
# [1000 rows x 6 columns]

# %%
new=np.array([[110,34,145,34.43,11,4323.43]])
j=model.predict(new)
j
# Out:
# c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but MeanShift was fitted with feature names
#   warnings.warn(
# array([4])
